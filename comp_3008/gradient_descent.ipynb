# %% [markdown]
# # Part 1: The method of Gradient Descent
#
# ### Goal:
# The goal of this project is to solve a system of equations (indirectly) using an alorithm known as gradient descent.

# %% [markdown]
# ## 1.4 Gradient Descent Project Example

# %%
from IPython.display import Image, display
import numpy as np
image_width=700
# Out:
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.

# %%
display(Image(filename='screenshots/1.4.1a.png', width=image_width), Image(filename='screenshots/1.4.1b.png', width=image_width))

# %% [markdown]
# ### 1.4.1 Properties of the gradient
#
# From the [desmos link](https://www.desmos.com/calculator/sduapnehxo), and playing around with two different functions, we see that the gradient is always perpendicular or orthogonal to the level set. After zooming in to where the level set looks flat, we can also see that moving perpendicular to the gradient (either left or the right) will result in no change in surface level i.e. the "altitude" moving along the level set will remain the same.
#
# Since the level sets are constant, the fastest way to change the height of the level set, is to away from the level set in the x-y plane. Moving away from the level set will be moving perpendicular to the level set. As we are given the fact that the gradient is increasing in direction and found that the gradient is perpendicular to the level set, we see that the gradient points in the direction that f(x,y) increases the fastest.

# %% [markdown]
# ### 1.4.2 Set Up

# %% [markdown]
# ### Defining the gradient
#
# In section 1.3, Background: Vectors and The Gradient, we are shown how a gradient can be constructed as well as its constraints:

# %%
display(Image(filename='screenshots/1.4.2e.png', width=image_width))

# %% [markdown]
# In the definition of a gradient, we know that for a multivariate function, its gradient can only be constructed if the output of that function maps to a single value (R^n --> R).
#
# Since we are trying to solve the system of equations in the components of f(x,y) using gradient descent, we want to assess if we can first calculate the gradient of f(x,y).
#
# Section 1.2 outlines f(x,y):
#
# ## $$ f(x,y) = <3x+y+1, 2x-y-1> = A\overrightarrow{x}-\overrightarrow{b} $$

# %%
#display(Image(filename='screenshots/1.4.2a.png', width=image_width))

# %% [markdown]
# For f(x,y), we see that it has two inputs, x and y, and two outputs 3x+y+1 and 2x-y-1 (R^2 --> R^2). In order to get the gradient of f(x,y), its output must map to a single value. Becuase of this, we cannot calculate the gradient of f(x,y) and have to find another function in order to calculate the gradient.

# %%
# (v) EXTRA work to build towards calculating L(x,y)
# how can we transform the output of f(x,y) to a single value?

# x and y example inputs for f(x,y)
x, y = 3, 1

# vector of f(3,1)
v = np.array([3*x + y + 1, 2*x - y - 1])
print('Vector of f(3,1)')
print(f'Two Inputs: x={x}, y={y}')
print(f'Two Outputs: {v}')

print('--- '*6)

# length of vector
length_vector = np.sqrt(v[0]**2 + v[1]**2)
print('Length of Vector')
print(f'Two Inputs: x={x}, y={y}')
print(f'One Output: Length of Vector={length_vector}')
# Out:
# Vector of f(3,1)
# Two Inputs: x=3, y=1
# Two Outputs: [11  4]
# --- --- --- --- --- ---
# Length of Vector
# Two Inputs: x=3, y=1
# One Output: Length of Vector=11.704699910719626

# %% [markdown]
# ### Computing the squared length of f(x,y), L(x,y):
# - Below, we calculate the squared length of f(x,y) similar to finding the squared length of a two-component vector as done in the previous example (v).
#     - || f(x,y) ||^2 = L(x,y)
# - We simply take the two components of f(x,y), square them, and then take their sum
# - Here, L(x,y) maps the two inputs of the x and y components to a single output
#
#
#
#
# ### Squared length of f(x,y):
# ### $$ ||f(x,y)||^2 = L(x,y) $$
# ### $$ f(x,y) = <3x+y+1, 2x-y-1> $$
# ### $$ L(x,y) = (3x+y+1)^2 + (2x-y-1)^2$$

# %%
#display(Image(filename='screenshots/1.4.2b.jpeg', width=image_width))

# %%
# (vii) - using the computed squared length of f(x,y)

# x and y inputs for f(x,y)
x, y = 3, 1

# squared length of f(x,y) = ||f(x,y)||^2 = L
L = (3*x + y + 1)**2 + (2*x-y-1)**2

# square root of L should match vector length of (v)
print('Squared Length')
print(f'Two Inputs: x={x}, y={y}')
print(f'One Output: Length of Vector={L}')

print('---'*6)
print(f'Square root of L(x,y): {np.sqrt(L)}')
# Out:
# Squared Length
# Two Inputs: x=3, y=1
# One Output: Length of Vector=137
# ------------------
# Square root of L(x,y): 11.704699910719626

# %% [markdown]
# In the cell above, we see that the vector length of f(x,y) at (3,1) is equal to the square root of the calculated square length of f(x,y), L(x,y), at the same point. Calculating L(x,y) maps the two inputs, x and y, to one output, the length squared. This will allow us to calculate the gradient of L(x,y).
#
# To further understand the relationship between f(x,y) and L(x,y) and how they will be used in gradient descent, we can ask ourselves:
#
# __"What condition is necessary for a vector ⟨a, b⟩ to have zero length?""__
#
# In order for the vector \<a, b> to have a zero length, a and b must be zero. So if the vector's length is 0, its components, a and b, must also be zero.
#
# In the context of f(x,y), the two component equations...
# 1. 3x + y + 1
# 2. 2x - y - 1
#
# ...must both be equal to zero in order for their their vector length to also be zero. This means that to find the solution to f(x,y) where f(x,y) = 0, its squared length, L(x,y) must also be equal to zero.
#
# With this relationship in mind, we can use L(x,y) to calculate the gradient.

# %% [markdown]
# ### Computing the gradient of L(x,y)
#
# - In order to compute the gradient of L(x,y), L(x,y) itself must first map two inputs to one output which we have just shown.
# - The next important step is to recognize that the gradient of L(x,y) will map two inputs to two outputs whose components are partial derivatives of L(x,y) which we went over in the defintion of a gradient
# - In the work below, we calculate the partial derivatives, dL/dL(x) and dL/dL(y), which make up the components of the gradient of L(x,y)
#
# ### $$ \nabla ||f(x,y)||^2 = \nabla L(x,y) =  <\frac{dL}{dx}, \frac{dL}{dy}> $$
# ### $$ L(x,y) = (3x+y+1)^2 + (2x-y-1)^2 $$
# #### $$ \frac{dL}{dx} = 6(3x+y+1) + 4(2x-y-1) $$
# #### $$       = 26x+2y+2 = 2(13x+y+1) $$
# #### $$ \frac{dL}{dy} = 2(3x+y+1) + 2(2x-y-1) $$
# #### $$       = 4y+2x+4 = 2(x+2y+2) $$
# ### $$ \nabla L(x,y) = <2(13x+y+1), 2(x+2y+2)> $$

# %%
#display(Image(filename='screenshots/1.4.2c.png', width=image_width))

# %% [markdown]
# ### Gradient of L(x,y) vs Matrix Multiplication of A^T(Ax-b)
# - From the gradient of L(x,y) we computed: \<2(13x+y+1), 2(x+2y+2)>
# - From the [symbolab link](https://www.symbolab.com/solver/step-by-step/%5Cbegin%7Bpmatrix%7D3%262%5C%5C%20%20%201%26-1%5Cend%7Bpmatrix%7D%5Cleft(%5Cbegin%7Bpmatrix%7D3%261%5C%5C%20%20%20%202%26-1%5Cend%7Bpmatrix%7D%5Cbegin%7Bpmatrix%7Dx%5C%5C%20%20%20%20y%5Cend%7Bpmatrix%7D-%5Cbegin%7Bpmatrix%7D-1%5C%5C%20%20%201%5Cend%7Bpmatrix%7D%5Cright)?or=input) where A^T(Ax-b) was calculated, the result was:
#     - [(13x+y+1)],[(x+2y+2)]]
#     - this is a 2x1 matrix
# - Based on these two observations, the gradient of the squared length of (Ax-b) is \<(13x+y+1), (x+2y+2)> as shown below:
#
# $$ A^T\left[ \left( \begin{matrix}
# 3 & 1  \\
# 2 & -1
# \end{matrix} \right) \left( \begin{matrix}
# x  \\
# y
# \end{matrix} \right) - \left( \begin{matrix}
# -1  \\
# 1
# \end{matrix} \right)\right] = \begin{pmatrix}
# 13x+y+1 \\
# x+2y+2
# \end{pmatrix}$$
#
# My guess for the general matrix formula for the gradient:
#
# #### $$ ||A\overrightarrow{x}-\overrightarrow{b}||^2 = \begin{pmatrix}
# 13x+y+1 \\
# x+2y+2
# \end{pmatrix} $$

# %%
#display(Image(filename='screenshots/1.4.2d.png', width=image_width))

# %% [markdown]
# ## 1.4.3 Investigating the method of Gradient Descent

# %% [markdown]
# The equation below is the general formula for a gradient descent function, g(x,y) where g maps two inputs to one output (R^2 --> R).
#
# The 2x1 vector, a_n, is the initial location of the points, x_0 and y_0. The coefficient, eta, is the "step size" by which to control how much of the gradient to subtract. The 2x1 vector, an_1, is the set of new points calculated after subtracting the gradient function multiplied by eta.
#
# # $$ \overrightarrow{a}_{n+1} = \overrightarrow{a}_{n}-\eta \nabla g(\overrightarrow{a}_{n}) $$

# %%
#display(Image(filename='screenshots/1.4.3a.png', width=image_width-200))

# %% [markdown]
# Gradient descent is a step-wise, recursive algorithim. It utilizes the gradient at a certain position in a function to move towards a local minimum of that function. The gradient represents the value that maps the partial derivatives of g(x,y) at a specific point as x/y components.
#
# As discussed earlier and using f(x,y) as the example, the gradient always points to the direction in which f(x,y) increases the fastest. Therefore, following the direction of the gradient will increase your poisition at the fastest rate relative to a point's current "height" and opposing the gradient (or subtracting the gradient) will decrease a points position at the fastest rate relative to its current "height". The amount of change per step of a point with the gradient can be varied using the coefficient, eta.
#
# So in gradient descent, you start at inital points of x0 and y0 and then subtract the gradient\*eta (which should take the point closer to a minimum). The algorithm does this over and over, each time setting new points and subtracting the gradient*eta, until you reach a gradient of 0 which equates to reaching a local minimum of f(x,y). In terms of how eta affects the gradient, the size of the eta coefficient can either make the steps to reaching your local minimum too small (if eta is a small value) or too big (if eta is too large) which can lead to over-shooting and not reaching a local minimum. In the two cases where eta is not an optimal value, gradient descent will take longer to reach the local minimum.

# %% [markdown]
# ### Brendt's implementation of Gradient Descent

# %%
import math
import numpy as np


def vecLength(v):
    tempSum = 0.0
    for x in v:
        tempSum += x[0]**2
    return math.sqrt(tempSum)


def f(A, b, x, y):
    temp = np.matrix([[x], [y]])
    return np.matrix(np.dot(A, temp) - b)

def grad(A, b, x, y):
    vec = np.matrix([[x], [y]])
    return np.matrix(2 * np.dot(np.transpose(A), np.dot(A, vec) - b))

def main():
    gamma = .02
    A = np.matrix([[3, 1], [2, -1]])
    b = np.matrix([[-1], [1]])
    x = 0.5
    y = -0.5
    step = 0
    while vecLength(grad(A, b, x, y)) > 0.0001:
        step += 1
        x = (np.matrix([[x], [y]]) - gamma * grad(A, b, x, y)).item(0)
        y = (np.matrix([[x], [y]]) - gamma * grad(A, b, x, y)).item(1)
        print("At step ", step, ":\n(x,y) = (", '{:10f}'.format(x), ", ", '{:10f}'.format(y), ")")
        print(
            "The magnitude squared (length squared) of the output of f, i.e.,||f(x,y)||^2=L(x,y) at this point is ",
            '{:12f}'.format(vecLength(f(A, b, x, y))**2))
        print("The magnitude (length) of the gradient at step ", step, " is ",
              '{:8f}'.format(vecLength(grad(A, b, x, y))))
        print('\n')
          
main()
# Out:
# At step  1 :
# (x,y) = (   0.220000 ,   -0.548800 )
# The magnitude squared (length squared) of the output of f, i.e.,||f(x,y)||^2=L(x,y) at this point is      1.234891
# The magnitude (length) of the gradient at step  1  is  6.992518
#
#
# At step  2 :
# (x,y) = (   0.087552 ,   -0.588398 )
# The magnitude squared (length squared) of the output of f, i.e.,||f(x,y)||^2=L(x,y) at this point is      0.510555
# The magnitude (length) of the gradient at step  2  is  3.595157
#
#
# At step  3 :
# (x,y) = (   0.025561 ,   -0.622349 )
# The magnitude squared (length squared) of the output of f, i.e.,||f(x,y)||^2=L(x,y) at this point is      0.313041
# The magnitude (length) of the gradient at step  3  is  2.110703
#
#
# At step  4 :
# (x,y) = (  -0.002837 ,   -0.652447 )
# The magnitude squared (length squared) of the output of f, i.e.,||f(x,y)||^2=L(x,y) at this point is      0.239718
# The magnitude (length) of the gradient at step  4  is  1.517569
#
#
# At step  5 :
# (x,y) = (  -0.015264 ,   -0.679641 )
# The magnitude squared (length squared) of the output of f, i.e.,||f(x,y)||^2=L(x,y) at this point is      0.198509
# The magnitude (length) of the gradient at step  5  is  1.274457
#
#
# At step  6 :
# (x,y) = (  -0.020141 ,   -0.704464 )
# The magnitude squared (length squared) of the output of f, i.e.,||f(x,y)||^2=L(x,y) at this point is      0.168052
# The magnitude (length) of the gradient at step  6  is  1.143850
#
#
# At step  7 :
# (x,y) = (  -0.021489 ,   -0.727247 )
# The magnitude squared (length squared) of the output of f, i.e.,||f(x,y)||^2=L(x,y) at this point is      0.143069
# The magnitude (length) of the gradient at step  7  is  1.048116
#
#
# At step  8 :
# (x,y) = (  -0.021225 ,   -0.748219 )
# The magnitude squared (length squared) of the output of f, i.e.,||f(x,y)||^2=L(x,y) at this point is      0.121956
# The magnitude (length) of the gradient at step  8  is  0.965884
#
#
# At step  9 :
# (x,y) = (  -0.020259 ,   -0.767551 )
# The magnitude squared (length squared) of the output of f, i.e.,||f(x,y)||^2=L(x,y) at this point is      0.103983
# The magnitude (length) of the gradient at step  9  is  0.891426
#
#
# At step  10 :
# (x,y) = (  -0.019022 ,   -0.785386 )
# The magnitude squared (length squared) of the output of f, i.e.,||f(x,y)||^2=L(x,y) at this point is      0.088658
# The magnitude (length) of the gradient at step  10  is  0.823011
#
#
# At step  11 :
# (x,y) = (  -0.017715 ,   -0.801846 )
# The magnitude squared (length squared) of the output of f, i.e.,||f(x,y)||^2=L(x,y) at this point is      0.075589
# The magnitude (length) of the gradient at step  11  is  0.759909
#
#
# At step  12 :
# (x,y) = (  -0.016429 ,   -0.817041 )
# The magnitude squared (length squared) of the output of f, i.e.,||f(x,y)||^2=L(x,y) at this point is      0.064445
# The magnitude (length) of the gradient at step  12  is  0.701654
#
#
# At step  13 :
# (x,y) = (  -0.015205 ,   -0.831070 )
# The magnitude squared (length squared) of the output of f, i.e.,||f(x,y)||^2=L(x,y) at this point is      0.054943
# The magnitude (length) of the gradient at step  13  is  0.647864
#
#
# At step  14 :
# (x,y) = (  -0.014055 ,   -0.844022 )
# The magnitude squared (length squared) of the output of f, i.e.,||f(x,y)||^2=L(x,y) at this point is      0.046842
# The magnitude (length) of the gradient at step  14  is  0.598197
#
#
# At step  15 :
# (x,y) = (  -0.012986 ,   -0.855981 )
# The magnitude squared (length squared) of the output of f, i.e.,||f(x,y)||^2=L(x,y) at this point is      0.039935
# The magnitude (length) of the gradient at step  15  is  0.552336
#
#
# At step  16 :
# (x,y) = (  -0.011994 ,   -0.867023 )
# The magnitude squared (length squared) of the output of f, i.e.,||f(x,y)||^2=L(x,y) at this point is      0.034046
# The magnitude (length) of the gradient at step  16  is  0.509990
#
#
# At step  17 :
# (x,y) = (  -0.011076 ,   -0.877218 )
# The magnitude squared (length squared) of the output of f, i.e.,||f(x,y)||^2=L(x,y) at this point is      0.029026
# The magnitude (length) of the gradient at step  17  is  0.470891
#
#
# At step  18 :
# (x,y) = (  -0.010228 ,   -0.886631 )
# The magnitude squared (length squared) of the output of f, i.e.,||f(x,y)||^2=L(x,y) at this point is      0.024746
# The magnitude (length) of the gradient at step  18  is  0.434789
#
#
# At step  19 :
# (x,y) = (  -0.009444 ,   -0.895323 )
# The magnitude squared (length squared) of the output of f, i.e.,||f(x,y)||^2=L(x,y) at this point is      0.021097
# The magnitude (length) of the gradient at step  19  is  0.401455
#
#
# At step  20 :
# (x,y) = (  -0.008720 ,   -0.903348 )
# The magnitude squared (length squared) of the output of f, i.e.,||f(x,y)||^2=L(x,y) at this point is      0.017986
# The magnitude (length) of the gradient at step  20  is  0.370676
#
#
# At step  21 :
# (x,y) = (  -0.008052 ,   -0.910758 )
# The magnitude squared (length squared) of the output of f, i.e.,||f(x,y)||^2=L(x,y) at this point is      0.015334
# The magnitude (length) of the gradient at step  21  is  0.342257
#
#
# At step  22 :
# (x,y) = (  -0.007435 ,   -0.917600 )
# The magnitude squared (length squared) of the output of f, i.e.,||f(x,y)||^2=L(x,y) at this point is      0.013073
# The magnitude (length) of the gradient at step  22  is  0.316017
#
#
# At step  23 :
# (x,y) = (  -0.006865 ,   -0.923918 )
# The magnitude squared (length squared) of the output of f, i.e.,||f(x,y)||^2=L(x,y) at this point is      0.011145
# The magnitude (length) of the gradient at step  23  is  0.291789
#
#
# At step  24 :
# (x,y) = (  -0.006338 ,   -0.929751 )
# The magnitude squared (length squared) of the output of f, i.e.,||f(x,y)||^2=L(x,y) at this point is      0.009502
# The magnitude (length) of the gradient at step  24  is  0.269418
#
#
# At step  25 :
# (x,y) = (  -0.005852 ,   -0.935137 )
# The magnitude squared (length squared) of the output of f, i.e.,||f(x,y)||^2=L(x,y) at this point is      0.008101
# The magnitude (length) of the gradient at step  25  is  0.248762
#
#
# At step  26 :
# (x,y) = (  -0.005404 ,   -0.940110 )
# The magnitude squared (length squared) of the output of f, i.e.,||f(x,y)||^2=L(x,y) at this point is      0.006906
# The magnitude (length) of the gradient at step  26  is  0.229690
#
#
# At step  27 :
# (x,y) = (  -0.004989 ,   -0.944701 )
# The magnitude squared (length squared) of the output of f, i.e.,||f(x,y)||^2=L(x,y) at this point is      0.005888
# The magnitude (length) of the gradient at step  27  is  0.212081
#
#
# At step  28 :
# (x,y) = (  -0.004607 ,   -0.948941 )
# The magnitude squared (length squared) of the output of f, i.e.,||f(x,y)||^2=L(x,y) at this point is      0.005020
# The magnitude (length) of the gradient at step  28  is  0.195821
#
#
# At step  29 :
# (x,y) = (  -0.004254 ,   -0.952855 )
# The magnitude squared (length squared) of the output of f, i.e.,||f(x,y)||^2=L(x,y) at this point is      0.004279
# The magnitude (length) of the gradient at step  29  is  0.180808
#
#
# At step  30 :
# (x,y) = (  -0.003928 ,   -0.956470 )
# The magnitude squared (length squared) of the output of f, i.e.,||f(x,y)||^2=L(x,y) at this point is      0.003648
# The magnitude (length) of the gradient at step  30  is  0.166946
#
#
# At step  31 :
# (x,y) = (  -0.003626 ,   -0.959807 )
# The magnitude squared (length squared) of the output of f, i.e.,||f(x,y)||^2=L(x,y) at this point is      0.003110
# The magnitude (length) of the gradient at step  31  is  0.154146
#
#
# At step  32 :
# (x,y) = (  -0.003348 ,   -0.962889 )
# The magnitude squared (length squared) of the output of f, i.e.,||f(x,y)||^2=L(x,y) at this point is      0.002652
# The magnitude (length) of the gradient at step  32  is  0.142328
#
#
# At step  33 :
# (x,y) = (  -0.003092 ,   -0.965734 )
# The magnitude squared (length squared) of the output of f, i.e.,||f(x,y)||^2=L(x,y) at this point is      0.002261
# The magnitude (length) of the gradient at step  33  is  0.131416
#
#
# At step  34 :
# (x,y) = (  -0.002855 ,   -0.968361 )
# The magnitude squared (length squared) of the output of f, i.e.,||f(x,y)||^2=L(x,y) at this point is      0.001927
# The magnitude (length) of the gradient at step  34  is  0.121341
#
#
# At step  35 :
# (x,y) = (  -0.002636 ,   -0.970787 )
# The magnitude squared (length squared) of the output of f, i.e.,||f(x,y)||^2=L(x,y) at this point is      0.001643
# The magnitude (length) of the gradient at step  35  is  0.112038
#
#
# At step  36 :
# (x,y) = (  -0.002434 ,   -0.973026 )
# The magnitude squared (length squared) of the output of f, i.e.,||f(x,y)||^2=L(x,y) at this point is      0.001401
# The magnitude (length) of the gradient at step  36  is  0.103448
#
#
# At step  37 :
# (x,y) = (  -0.002247 ,   -0.975094 )
# The magnitude squared (length squared) of the output of f, i.e.,||f(x,y)||^2=L(x,y) at this point is      0.001194
# The magnitude (length) of the gradient at step  37  is  0.095517
#
#
# At step  38 :
# (x,y) = (  -0.002075 ,   -0.977004 )
# The magnitude squared (length squared) of the output of f, i.e.,||f(x,y)||^2=L(x,y) at this point is      0.001018
# The magnitude (length) of the gradient at step  38  is  0.088194
#
#
# At step  39 :
# (x,y) = (  -0.001916 ,   -0.978767 )
# The magnitude squared (length squared) of the output of f, i.e.,||f(x,y)||^2=L(x,y) at this point is      0.000868
# The magnitude (length) of the gradient at step  39  is  0.081432
#
#
# At step  40 :
# (x,y) = (  -0.001769 ,   -0.980395 )
# The magnitude squared (length squared) of the output of f, i.e.,||f(x,y)||^2=L(x,y) at this point is      0.000740
# The magnitude (length) of the gradient at step  40  is  0.075189
#
#
# At step  41 :
# (x,y) = (  -0.001633 ,   -0.981898 )
# The magnitude squared (length squared) of the output of f, i.e.,||f(x,y)||^2=L(x,y) at this point is      0.000631
# The magnitude (length) of the gradient at step  41  is  0.069425
#
#
# At step  42 :
# (x,y) = (  -0.001508 ,   -0.983286 )
# The magnitude squared (length squared) of the output of f, i.e.,||f(x,y)||^2=L(x,y) at this point is      0.000538
# The magnitude (length) of the gradient at step  42  is  0.064102
#
#
# At step  43 :
# (x,y) = (  -0.001392 ,   -0.984567 )
# The magnitude squared (length squared) of the output of f, i.e.,||f(x,y)||^2=L(x,y) at this point is      0.000459
# The magnitude (length) of the gradient at step  43  is  0.059187
#
#
# At step  44 :
# (x,y) = (  -0.001286 ,   -0.985750 )
# The magnitude squared (length squared) of the output of f, i.e.,||f(x,y)||^2=L(x,y) at this point is      0.000391
# The magnitude (length) of the gradient at step  44  is  0.054650
#
#
# At step  45 :
# (x,y) = (  -0.001187 ,   -0.986843 )
# The magnitude squared (length squared) of the output of f, i.e.,||f(x,y)||^2=L(x,y) at this point is      0.000333
# The magnitude (length) of the gradient at step  45  is  0.050460
#
#
# At step  46 :
# (x,y) = (  -0.001096 ,   -0.987852 )
# The magnitude squared (length squared) of the output of f, i.e.,||f(x,y)||^2=L(x,y) at this point is      0.000284
# The magnitude (length) of the gradient at step  46  is  0.046591
#
#
# At step  47 :
# (x,y) = (  -0.001012 ,   -0.988783 )
# The magnitude squared (length squared) of the output of f, i.e.,||f(x,y)||^2=L(x,y) at this point is      0.000242
# The magnitude (length) of the gradient at step  47  is  0.043019
#
#
# At step  48 :
# (x,y) = (  -0.000934 ,   -0.989643 )
# The magnitude squared (length squared) of the output of f, i.e.,||f(x,y)||^2=L(x,y) at this point is      0.000207
# The magnitude (length) of the gradient at step  48  is  0.039721
#
#
# At step  49 :
# (x,y) = (  -0.000863 ,   -0.990437 )
# The magnitude squared (length squared) of the output of f, i.e.,||f(x,y)||^2=L(x,y) at this point is      0.000176
# The magnitude (length) of the gradient at step  49  is  0.036676
#
#
# At step  50 :
# (x,y) = (  -0.000797 ,   -0.991170 )
# The magnitude squared (length squared) of the output of f, i.e.,||f(x,y)||^2=L(x,y) at this point is      0.000150
# The magnitude (length) of the gradient at step  50  is  0.033864
#
#
# At step  51 :
# (x,y) = (  -0.000736 ,   -0.991847 )
# The magnitude squared (length squared) of the output of f, i.e.,||f(x,y)||^2=L(x,y) at this point is      0.000128
# The magnitude (length) of the gradient at step  51  is  0.031268
#
#
# At step  52 :
# (x,y) = (  -0.000679 ,   -0.992472 )
# The magnitude squared (length squared) of the output of f, i.e.,||f(x,y)||^2=L(x,y) at this point is      0.000109
# The magnitude (length) of the gradient at step  52  is  0.028870
#
#
# At step  53 :
# (x,y) = (  -0.000627 ,   -0.993049 )
# The magnitude squared (length squared) of the output of f, i.e.,||f(x,y)||^2=L(x,y) at this point is      0.000093
# The magnitude (length) of the gradient at step  53  is  0.026657
#
#
# At step  54 :
# (x,y) = (  -0.000579 ,   -0.993582 )
# The magnitude squared (length squared) of the output of f, i.e.,||f(x,y)||^2=L(x,y) at this point is      0.000079
# The magnitude (length) of the gradient at step  54  is  0.024613
#
#
# At step  55 :
# (x,y) = (  -0.000535 ,   -0.994074 )
# The magnitude squared (length squared) of the output of f, i.e.,||f(x,y)||^2=L(x,y) at this point is      0.000068
# The magnitude (length) of the gradient at step  55  is  0.022726
#
#
# At step  56 :
# (x,y) = (  -0.000494 ,   -0.994529 )
# The magnitude squared (length squared) of the output of f, i.e.,||f(x,y)||^2=L(x,y) at this point is      0.000058
# The magnitude (length) of the gradient at step  56  is  0.020984
#
#
# At step  57 :
# (x,y) = (  -0.000456 ,   -0.994948 )
# The magnitude squared (length squared) of the output of f, i.e.,||f(x,y)||^2=L(x,y) at this point is      0.000049
# The magnitude (length) of the gradient at step  57  is  0.019375
#
#
# At step  58 :
# (x,y) = (  -0.000421 ,   -0.995335 )
# The magnitude squared (length squared) of the output of f, i.e.,||f(x,y)||^2=L(x,y) at this point is      0.000042
# The magnitude (length) of the gradient at step  58  is  0.017890
#
#
# At step  59 :
# (x,y) = (  -0.000389 ,   -0.995693 )
# The magnitude squared (length squared) of the output of f, i.e.,||f(x,y)||^2=L(x,y) at this point is      0.000036
# The magnitude (length) of the gradient at step  59  is  0.016518
#
#
# At step  60 :
# (x,y) = (  -0.000359 ,   -0.996023 )
# The magnitude squared (length squared) of the output of f, i.e.,||f(x,y)||^2=L(x,y) at this point is      0.000030
# The magnitude (length) of the gradient at step  60  is  0.015252
#
#
# At step  61 :
# (x,y) = (  -0.000331 ,   -0.996328 )
# The magnitude squared (length squared) of the output of f, i.e.,||f(x,y)||^2=L(x,y) at this point is      0.000026
# The magnitude (length) of the gradient at step  61  is  0.014082
#
#
# At step  62 :
# (x,y) = (  -0.000306 ,   -0.996610 )
# The magnitude squared (length squared) of the output of f, i.e.,||f(x,y)||^2=L(x,y) at this point is      0.000022
# The magnitude (length) of the gradient at step  62  is  0.013003
#
#
# At step  63 :
# (x,y) = (  -0.000282 ,   -0.996870 )
# The magnitude squared (length squared) of the output of f, i.e.,||f(x,y)||^2=L(x,y) at this point is      0.000019
# The magnitude (length) of the gradient at step  63  is  0.012006
#
#
# At step  64 :
# (x,y) = (  -0.000261 ,   -0.997110 )
# The magnitude squared (length squared) of the output of f, i.e.,||f(x,y)||^2=L(x,y) at this point is      0.000016
# The magnitude (length) of the gradient at step  64  is  0.011085
#
#
# At step  65 :
# (x,y) = (  -0.000241 ,   -0.997331 )
# The magnitude squared (length squared) of the output of f, i.e.,||f(x,y)||^2=L(x,y) at this point is      0.000014
# The magnitude (length) of the gradient at step  65  is  0.010235
#
#
# At step  66 :
# (x,y) = (  -0.000222 ,   -0.997536 )
# The magnitude squared (length squared) of the output of f, i.e.,||f(x,y)||^2=L(x,y) at this point is      0.000012
# The magnitude (length) of the gradient at step  66  is  0.009451
#
#
# At step  67 :
# (x,y) = (  -0.000205 ,   -0.997725 )
# The magnitude squared (length squared) of the output of f, i.e.,||f(x,y)||^2=L(x,y) at this point is      0.000010
# The magnitude (length) of the gradient at step  67  is  0.008726
#
#
# At step  68 :
# (x,y) = (  -0.000190 ,   -0.997899 )
# The magnitude squared (length squared) of the output of f, i.e.,||f(x,y)||^2=L(x,y) at this point is      0.000008
# The magnitude (length) of the gradient at step  68  is  0.008057
#
#
# At step  69 :
# (x,y) = (  -0.000175 ,   -0.998060 )
# The magnitude squared (length squared) of the output of f, i.e.,||f(x,y)||^2=L(x,y) at this point is      0.000007
# The magnitude (length) of the gradient at step  69  is  0.007439
#
#
# At step  70 :
# (x,y) = (  -0.000162 ,   -0.998209 )
# The magnitude squared (length squared) of the output of f, i.e.,||f(x,y)||^2=L(x,y) at this point is      0.000006
# The magnitude (length) of the gradient at step  70  is  0.006869
#
#
# At step  71 :
# (x,y) = (  -0.000149 ,   -0.998346 )
# The magnitude squared (length squared) of the output of f, i.e.,||f(x,y)||^2=L(x,y) at this point is      0.000005
# The magnitude (length) of the gradient at step  71  is  0.006342
#
#
# At step  72 :
# (x,y) = (  -0.000138 ,   -0.998473 )
# The magnitude squared (length squared) of the output of f, i.e.,||f(x,y)||^2=L(x,y) at this point is      0.000004
# The magnitude (length) of the gradient at step  72  is  0.005856
#
#
# At step  73 :
# (x,y) = (  -0.000127 ,   -0.998590 )
# The magnitude squared (length squared) of the output of f, i.e.,||f(x,y)||^2=L(x,y) at this point is      0.000004
# The magnitude (length) of the gradient at step  73  is  0.005407
#
#
# At step  74 :
# (x,y) = (  -0.000117 ,   -0.998698 )
# The magnitude squared (length squared) of the output of f, i.e.,||f(x,y)||^2=L(x,y) at this point is      0.000003
# The magnitude (length) of the gradient at step  74  is  0.004993
#
#
# At step  75 :
# (x,y) = (  -0.000108 ,   -0.998798 )
# The magnitude squared (length squared) of the output of f, i.e.,||f(x,y)||^2=L(x,y) at this point is      0.000003
# The magnitude (length) of the gradient at step  75  is  0.004610
#
#
# At step  76 :
# (x,y) = (  -0.000100 ,   -0.998890 )
# The magnitude squared (length squared) of the output of f, i.e.,||f(x,y)||^2=L(x,y) at this point is      0.000002
# The magnitude (length) of the gradient at step  76  is  0.004256
#
#
# At step  77 :
# (x,y) = (  -0.000092 ,   -0.998975 )
# The magnitude squared (length squared) of the output of f, i.e.,||f(x,y)||^2=L(x,y) at this point is      0.000002
# The magnitude (length) of the gradient at step  77  is  0.003930
#
#
# At step  78 :
# (x,y) = (  -0.000085 ,   -0.999054 )
# The magnitude squared (length squared) of the output of f, i.e.,||f(x,y)||^2=L(x,y) at this point is      0.000002
# The magnitude (length) of the gradient at step  78  is  0.003629
#
#
# At step  79 :
# (x,y) = (  -0.000079 ,   -0.999126 )
# The magnitude squared (length squared) of the output of f, i.e.,||f(x,y)||^2=L(x,y) at this point is      0.000001
# The magnitude (length) of the gradient at step  79  is  0.003351
#
#
# At step  80 :
# (x,y) = (  -0.000073 ,   -0.999193 )
# The magnitude squared (length squared) of the output of f, i.e.,||f(x,y)||^2=L(x,y) at this point is      0.000001
# The magnitude (length) of the gradient at step  80  is  0.003094
#
#
# At step  81 :
# (x,y) = (  -0.000067 ,   -0.999255 )
# The magnitude squared (length squared) of the output of f, i.e.,||f(x,y)||^2=L(x,y) at this point is      0.000001
# The magnitude (length) of the gradient at step  81  is  0.002857
#
#
# At step  82 :
# (x,y) = (  -0.000062 ,   -0.999312 )
# The magnitude squared (length squared) of the output of f, i.e.,||f(x,y)||^2=L(x,y) at this point is      0.000001
# The magnitude (length) of the gradient at step  82  is  0.002638
#
#
# At step  83 :
# (x,y) = (  -0.000057 ,   -0.999365 )
# The magnitude squared (length squared) of the output of f, i.e.,||f(x,y)||^2=L(x,y) at this point is      0.000001
# The magnitude (length) of the gradient at step  83  is  0.002435
#
#
# At step  84 :
# (x,y) = (  -0.000053 ,   -0.999414 )
# The magnitude squared (length squared) of the output of f, i.e.,||f(x,y)||^2=L(x,y) at this point is      0.000001
# The magnitude (length) of the gradient at step  84  is  0.002249
#
#
# At step  85 :
# (x,y) = (  -0.000049 ,   -0.999459 )
# The magnitude squared (length squared) of the output of f, i.e.,||f(x,y)||^2=L(x,y) at this point is      0.000001
# The magnitude (length) of the gradient at step  85  is  0.002076
#
#
# At step  86 :
# (x,y) = (  -0.000045 ,   -0.999500 )
# The magnitude squared (length squared) of the output of f, i.e.,||f(x,y)||^2=L(x,y) at this point is      0.000000
# The magnitude (length) of the gradient at step  86  is  0.001917
#
#
# At step  87 :
# (x,y) = (  -0.000042 ,   -0.999538 )
# The magnitude squared (length squared) of the output of f, i.e.,||f(x,y)||^2=L(x,y) at this point is      0.000000
# The magnitude (length) of the gradient at step  87  is  0.001770
#
#
# At step  88 :
# (x,y) = (  -0.000038 ,   -0.999574 )
# The magnitude squared (length squared) of the output of f, i.e.,||f(x,y)||^2=L(x,y) at this point is      0.000000
# The magnitude (length) of the gradient at step  88  is  0.001634
#
#
# At step  89 :
# (x,y) = (  -0.000036 ,   -0.999607 )
# The magnitude squared (length squared) of the output of f, i.e.,||f(x,y)||^2=L(x,y) at this point is      0.000000
# The magnitude (length) of the gradient at step  89  is  0.001509
#
#
# At step  90 :
# (x,y) = (  -0.000033 ,   -0.999637 )
# The magnitude squared (length squared) of the output of f, i.e.,||f(x,y)||^2=L(x,y) at this point is      0.000000
# The magnitude (length) of the gradient at step  90  is  0.001393
#
#
# At step  91 :
# (x,y) = (  -0.000030 ,   -0.999665 )
# The magnitude squared (length squared) of the output of f, i.e.,||f(x,y)||^2=L(x,y) at this point is      0.000000
# The magnitude (length) of the gradient at step  91  is  0.001287
#
#
# At step  92 :
# (x,y) = (  -0.000028 ,   -0.999690 )
# The magnitude squared (length squared) of the output of f, i.e.,||f(x,y)||^2=L(x,y) at this point is      0.000000
# The magnitude (length) of the gradient at step  92  is  0.001188
#
#
# At step  93 :
# (x,y) = (  -0.000026 ,   -0.999714 )
# The magnitude squared (length squared) of the output of f, i.e.,||f(x,y)||^2=L(x,y) at this point is      0.000000
# The magnitude (length) of the gradient at step  93  is  0.001097
#
#
# At step  94 :
# (x,y) = (  -0.000024 ,   -0.999736 )
# The magnitude squared (length squared) of the output of f, i.e.,||f(x,y)||^2=L(x,y) at this point is      0.000000
# The magnitude (length) of the gradient at step  94  is  0.001013
#
#
# At step  95 :
# (x,y) = (  -0.000022 ,   -0.999756 )
# The magnitude squared (length squared) of the output of f, i.e.,||f(x,y)||^2=L(x,y) at this point is      0.000000
# The magnitude (length) of the gradient at step  95  is  0.000935
#
#
# At step  96 :
# (x,y) = (  -0.000020 ,   -0.999775 )
# The magnitude squared (length squared) of the output of f, i.e.,||f(x,y)||^2=L(x,y) at this point is      0.000000
# The magnitude (length) of the gradient at step  96  is  0.000863
#
#
# At step  97 :
# (x,y) = (  -0.000019 ,   -0.999792 )
# The magnitude squared (length squared) of the output of f, i.e.,||f(x,y)||^2=L(x,y) at this point is      0.000000
# The magnitude (length) of the gradient at step  97  is  0.000797
#
#
# At step  98 :
# (x,y) = (  -0.000017 ,   -0.999808 )
# The magnitude squared (length squared) of the output of f, i.e.,||f(x,y)||^2=L(x,y) at this point is      0.000000
# The magnitude (length) of the gradient at step  98  is  0.000736
#
#
# At step  99 :
# (x,y) = (  -0.000016 ,   -0.999823 )
# The magnitude squared (length squared) of the output of f, i.e.,||f(x,y)||^2=L(x,y) at this point is      0.000000
# The magnitude (length) of the gradient at step  99  is  0.000680
#
#
# At step  100 :
# (x,y) = (  -0.000015 ,   -0.999836 )
# The magnitude squared (length squared) of the output of f, i.e.,||f(x,y)||^2=L(x,y) at this point is      0.000000
# The magnitude (length) of the gradient at step  100  is  0.000628
#
#
# At step  101 :
# (x,y) = (  -0.000014 ,   -0.999849 )
# The magnitude squared (length squared) of the output of f, i.e.,||f(x,y)||^2=L(x,y) at this point is      0.000000
# The magnitude (length) of the gradient at step  101  is  0.000579
#
#
# At step  102 :
# (x,y) = (  -0.000013 ,   -0.999861 )
# The magnitude squared (length squared) of the output of f, i.e.,||f(x,y)||^2=L(x,y) at this point is      0.000000
# The magnitude (length) of the gradient at step  102  is  0.000535
#
#
# At step  103 :
# (x,y) = (  -0.000012 ,   -0.999871 )
# The magnitude squared (length squared) of the output of f, i.e.,||f(x,y)||^2=L(x,y) at this point is      0.000000
# The magnitude (length) of the gradient at step  103  is  0.000494
#
#
# At step  104 :
# (x,y) = (  -0.000011 ,   -0.999881 )
# The magnitude squared (length squared) of the output of f, i.e.,||f(x,y)||^2=L(x,y) at this point is      0.000000
# The magnitude (length) of the gradient at step  104  is  0.000456
#
#
# At step  105 :
# (x,y) = (  -0.000010 ,   -0.999890 )
# The magnitude squared (length squared) of the output of f, i.e.,||f(x,y)||^2=L(x,y) at this point is      0.000000
# The magnitude (length) of the gradient at step  105  is  0.000421
#
#
# At step  106 :
# (x,y) = (  -0.000009 ,   -0.999899 )
# The magnitude squared (length squared) of the output of f, i.e.,||f(x,y)||^2=L(x,y) at this point is      0.000000
# The magnitude (length) of the gradient at step  106  is  0.000389
#
#
# At step  107 :
# (x,y) = (  -0.000008 ,   -0.999906 )
# The magnitude squared (length squared) of the output of f, i.e.,||f(x,y)||^2=L(x,y) at this point is      0.000000
# The magnitude (length) of the gradient at step  107  is  0.000359
#
#
# At step  108 :
# (x,y) = (  -0.000008 ,   -0.999914 )
# The magnitude squared (length squared) of the output of f, i.e.,||f(x,y)||^2=L(x,y) at this point is      0.000000
# The magnitude (length) of the gradient at step  108  is  0.000332
#
#
# At step  109 :
# (x,y) = (  -0.000007 ,   -0.999920 )
# The magnitude squared (length squared) of the output of f, i.e.,||f(x,y)||^2=L(x,y) at this point is      0.000000
# The magnitude (length) of the gradient at step  109  is  0.000306
#
#
# At step  110 :
# (x,y) = (  -0.000007 ,   -0.999926 )
# The magnitude squared (length squared) of the output of f, i.e.,||f(x,y)||^2=L(x,y) at this point is      0.000000
# The magnitude (length) of the gradient at step  110  is  0.000283
#
#
# At step  111 :
# (x,y) = (  -0.000006 ,   -0.999932 )
# The magnitude squared (length squared) of the output of f, i.e.,||f(x,y)||^2=L(x,y) at this point is      0.000000
# The magnitude (length) of the gradient at step  111  is  0.000261
#
#
# At step  112 :
# (x,y) = (  -0.000006 ,   -0.999937 )
# The magnitude squared (length squared) of the output of f, i.e.,||f(x,y)||^2=L(x,y) at this point is      0.000000
# The magnitude (length) of the gradient at step  112  is  0.000241
#
#
# At step  113 :
# (x,y) = (  -0.000005 ,   -0.999942 )
# The magnitude squared (length squared) of the output of f, i.e.,||f(x,y)||^2=L(x,y) at this point is      0.000000
# The magnitude (length) of the gradient at step  113  is  0.000222
#
#
# At step  114 :
# (x,y) = (  -0.000005 ,   -0.999946 )
# The magnitude squared (length squared) of the output of f, i.e.,||f(x,y)||^2=L(x,y) at this point is      0.000000
# The magnitude (length) of the gradient at step  114  is  0.000205
#
#
# At step  115 :
# (x,y) = (  -0.000004 ,   -0.999951 )
# The magnitude squared (length squared) of the output of f, i.e.,||f(x,y)||^2=L(x,y) at this point is      0.000000
# The magnitude (length) of the gradient at step  115  is  0.000190
#
#
# At step  116 :
# (x,y) = (  -0.000004 ,   -0.999954 )
# The magnitude squared (length squared) of the output of f, i.e.,||f(x,y)||^2=L(x,y) at this point is      0.000000
# The magnitude (length) of the gradient at step  116  is  0.000175
#
#
# At step  117 :
# (x,y) = (  -0.000004 ,   -0.999958 )
# The magnitude squared (length squared) of the output of f, i.e.,||f(x,y)||^2=L(x,y) at this point is      0.000000
# The magnitude (length) of the gradient at step  117  is  0.000162
#
#
# At step  118 :
# (x,y) = (  -0.000004 ,   -0.999961 )
# The magnitude squared (length squared) of the output of f, i.e.,||f(x,y)||^2=L(x,y) at this point is      0.000000
# The magnitude (length) of the gradient at step  118  is  0.000149
#
#
# At step  119 :
# (x,y) = (  -0.000003 ,   -0.999964 )
# The magnitude squared (length squared) of the output of f, i.e.,||f(x,y)||^2=L(x,y) at this point is      0.000000
# The magnitude (length) of the gradient at step  119  is  0.000138
#
#
# At step  120 :
# (x,y) = (  -0.000003 ,   -0.999967 )
# The magnitude squared (length squared) of the output of f, i.e.,||f(x,y)||^2=L(x,y) at this point is      0.000000
# The magnitude (length) of the gradient at step  120  is  0.000127
#
#
# At step  121 :
# (x,y) = (  -0.000003 ,   -0.999969 )
# The magnitude squared (length squared) of the output of f, i.e.,||f(x,y)||^2=L(x,y) at this point is      0.000000
# The magnitude (length) of the gradient at step  121  is  0.000118
#
#
# At step  122 :
# (x,y) = (  -0.000003 ,   -0.999972 )
# The magnitude squared (length squared) of the output of f, i.e.,||f(x,y)||^2=L(x,y) at this point is      0.000000
# The magnitude (length) of the gradient at step  122  is  0.000109
#
#
# At step  123 :
# (x,y) = (  -0.000002 ,   -0.999974 )
# The magnitude squared (length squared) of the output of f, i.e.,||f(x,y)||^2=L(x,y) at this point is      0.000000
# The magnitude (length) of the gradient at step  123  is  0.000100
#
#
# At step  124 :
# (x,y) = (  -0.000002 ,   -0.999976 )
# The magnitude squared (length squared) of the output of f, i.e.,||f(x,y)||^2=L(x,y) at this point is      0.000000
# The magnitude (length) of the gradient at step  124  is  0.000093

# %% [markdown]
# Based on the code above, the initial (x,y) pair starts at (0.5, -0.5) with a gamma (eta) set at 0.2. At each step, the gradient is calculated, the gamma\*gradient is subtracted from the (x,y) pair, and this process repeats until the gradient is below 0.0001.
#
# At each step of gradient descent, the (x,y) pairs are approaching 0 and -1 respectively while L(x,y) and the gradient of L(x,y) approach 0.
#
# We can check the results of Brendt's implementation of gradient descent by plugging in x=0 and y=-1 into the squared length of f(x,y):

# %%
# x and y inputs found from gradient descent
x, y = 0, -1

# squared length of f(x,y) = ||f(x,y)||^2 = L
L = (3*x + y + 1)**2 + (2*x-y-1)**2

# expect squared length to be 0
L
# Out:
# 0

# %% [markdown]
# As expected, the squared length is in fact 0!
#
# Earlier, we discussed the fact that you cannot take the gradient of f(x,y) since f(x,y) has two outputs while you can take the gradient of L(x,y) since L(x,y) returns a single output. In order to calculate the new points of of a_n with gradient descent, you need to be able to calculate the gradient of the function. For f(x,y), it is not possible to calculate the gradient and therefore, not possible to use gradient descent. The opposite is true for L(x,y) which is why we can calculate the gradient of L(x,y) and can use it in gradient descent.
#
# Remember that the function that we are trying to find the solution for, is f(x,y). To find the solution, f(x,y) must be equal to zero. As stated above, we cannot use f(x,y) directly to calculate the gradient in order to minimize f(x,y). However, the squared length of f(x,y), L(x,y) can be used. If the squared length of of f(x,y) is 0 i.e L(x,y) = 0, then f(x,y) will also equal zero as we outlined earlier in the notebook. Therefore L(x,y) is an alternative function that we can utilize in gradient descent to iteratively arrive to a minimum of f(x,y) in order to find the solution.
#
# So in a sense, L(x,y) represents how far or close f(x,y) is to being equal to zero. That is, the closer L(x,y) is to zero, the closer f(x,y) is to being equal to zero as well, and the closer we get to the solution pair (x,y) for which f(x,y) = 0.
#
# Again, from the Python code above, we see that x approachs 0 and y approaches -1 with each step of gradient descent. We can plug these values directly into f(x,y) like we did for the squared length of f(x,y) to confirm the results:

# %%
# x and y inputs for f(x,y) as calculated by gradient descent
x, y = 0, -1

# vector of f(0,-1)
v = np.array([3*x + y + 1, 2*x - y - 1])

# length of vector expected to be 0
length_vector = np.sqrt(v[0]**2 + v[1]**2)
print(length_vector)
# Out:
# 0.0

# %% [markdown]
# With the pair (0,-1) found through gradient descent, we get f(0,-1) = 0 thus showing that we arrived at the correct solution pair!

# %% [markdown]
# # Part 2: Hardest Question of the year
#
# - I would want to be lower case z (in cursive)
# 1. It's fun to write
# 2. It's a pretty letter
# 3. Even if I rush and write it a little sloppy, 'z' still looks cool haha

# %% [markdown]
# # Part 3: Extra Credit

# %%
display(Image(filename='screenshots/ec_1.png', width=image_width))

# %%
display(Image(filename='screenshots/ec_2.png', width=image_width))

# %%
display(Image(filename='screenshots/ec_3.png', width=image_width))
